# %%
from Operaciones import Distribucion

bd = Distribucion(5, .10)
bd.Binomial()
# Out:
#         Binomial
# Tests
# 0     0.53144100
# 1     0.35429400
# 2     0.09841500
# 3     0.01458000
# 4     0.00121500
# 5     0.00005400
